# %% [markdown]
# ### Creación de histograma usando matriz numpy

# %%
import matplotlib.pyplot as plt #importing matplotlib

img = plt.imread('image/flower.png') # lee los datos de la imagen

#creacion de histograma
# calculate frequency of pixels in range 0-255 
plt.hist(img.ravel(), bins=256, range=(0.0, 1.0), fc='k', ec='k') #calculating histogram
# Out:
# (array([71007., 21888., 12566.,  6777.,  3876.,  2640.,  2142.,  1744.,
#          1489.,  1368.,  1301.,  1301.,  1260.,  1257.,  1178.,  1164.,
#          1154.,  1030.,  1033.,  1024.,  1069.,  1027.,  1002.,   988.,
#           975.,   952.,   927.,   895.,   900.,   967.,   910.,   914.,
#           852.,   747.,   783.,   749.,   780.,   707.,   746.,   661.,
#           681.,   653.,   645.,   718.,   691.,   718.,   648.,   673.,
#           701.,   707.,   647.,   690.,   684.,   676.,   663.,   683.,
#           677.,   690.,   686.,   680.,   621.,   670.,   576.,   695.,
#           607.,   595.,   642.,   606.,   645.,   629.,   631.,   624.,
#           548.,   574.,   569.,   515.,   528.,   490.,   521.,   510.,
#           470.,   497.,   496.,   528.,   511.,   508.,   497.,   534.,
#           503.,   508.,   513.,   455.,   472.,   465.,   436.,   421.,
#           446.,   446.,   426.,   405.,   425.,   389.,   425.,   402.,
# ...

# %% [markdown]
# ### Trazado de histogramas utilizando Matplotlib

# %%
# importing required libraries of opencv 
import cv2 
from matplotlib import pyplot as plt 

# reads an input image 
img = cv2.imread('image/perro.jpg',0) 

# find frequency of pixels in range 0-255 
histr = cv2.calcHist([img],[0],None,[256],[0,256])

# show the plotting graph of an image 
plt.plot(histr) 
plt.show()

# %%
import cv2 
from matplotlib import pyplot as plt 
img = cv2.imread('image/perro.jpg',0) 

# alternative way to find histogram of an image 
plt.hist(img.ravel(),256,[0,256]) 
plt.show()
